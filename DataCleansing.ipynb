# %% [markdown]
# ## Data Cleansing and Transformation using the Mode method:

# %% [markdown]
# ### Importing Libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data1 = pd.read_excel(r'C:\Users\Jyothi Nair\Desktop\Data Glacier\bank-additional.xlsx')

# %%
data2 = pd.read_excel(r'C:\Users\Jyothi Nair\Desktop\Data Glacier\bank-additional-full.xlsx')

# %% [markdown]
# ### Dealing with null values:

# %%
data1.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
data2.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %% [markdown]
# As the total number of entries match the non-null values for each column, there are no null values to be found.

# %% [markdown]
# ### Imputation of missing values:

# %%
missing1 = [var for var in data1.columns if data1[var].dtypes == 'O']
missing2 = [var for var in data2.columns if data2[var].dtypes == 'O']

# %% [markdown]
# The above statements check for categorical datatypes in our datasets. 'O' is used to check for object datatypes.

# %%
missing1
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome',
#  'y']

# %%
missing2
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome',
#  'y']

# %% [markdown]
# We see that both datasets have the same categorical datatypes.

# %% [markdown]
# ### Imputing missing values using Mode:

# %% [markdown]
# Using the mode function, we find out what the most common occurance is for each of these datatypes, and then replace all unknown values with the mode.

# %%
data1['job'].mode()
# Out:
# 0    admin.
# dtype: object

# %%
data2['job'].mode()
# Out:
# 0    admin.
# dtype: object

# %%
data1['job'].replace('unknown', 'admin', inplace = True)
data2['job'].replace('unknown', 'admin', inplace = True)

# %%
data1['marital'].mode()
# Out:
# 0    married
# dtype: object

# %%
data2['marital'].mode()
# Out:
# 0    married
# dtype: object

# %%
data1['marital'].replace('unknown', 'married', inplace = True)
data2['marital'].replace('unknown', 'married', inplace = True)

# %%
data1['default'].mode()
# Out:
# 0    no
# dtype: object

# %%
data2['default'].mode()
# Out:
# 0    no
# dtype: object

# %%
data1['default'].replace('unknown', 'no', inplace = True)
data2['default'].replace('unknown', 'no', inplace = True)

# %%
data1['housing'].mode()
# Out:
# 0    yes
# dtype: object

# %%
data2['housing'].mode()
# Out:
# 0    yes
# dtype: object

# %%
data1['housing'].replace('unknown', 'yes', inplace = True)
data2['housing'].replace('unknown', 'yes', inplace = True)

# %%
data1['loan'].mode()
# Out:
# 0    no
# dtype: object

# %%
data2['loan'].mode()
# Out:
# 0    no
# dtype: object

# %%
data1['loan'].replace('unknown', 'no', inplace = True)
data2['loan'].replace('unknown', 'no', inplace = True)

# %%
data1['contact'].mode()
# Out:
# 0    cellular
# dtype: object

# %%
data2['contact'].mode()
# Out:
# 0    cellular
# dtype: object

# %%
data1['contact'].replace('unknown', 'cellular', inplace = True)
data2['contact'].replace('unknown', 'cellular', inplace = True)

# %%
data1['month'].mode()
# Out:
# 0    may
# dtype: object

# %%
data2['month'].mode()
# Out:
# 0    may
# dtype: object

# %%
data1['month'].replace('unknown', 'may', inplace = True)
data2['month'].replace('unknown', 'may', inplace = True)

# %%
data1['day_of_week'].mode()
# Out:
# 0    thu
# dtype: object

# %%
data2['day_of_week'].mode()
# Out:
# 0    thu
# dtype: object

# %%
data1['day_of_week'].replace('unknown', 'thu', inplace = True)
data2['day_of_week'].replace('unknown', 'thu', inplace = True)

# %%
data1['poutcome'].mode()
# Out:
# 0    nonexistent
# dtype: object

# %%
data1['poutcome'].mode()
# Out:
# 0    nonexistent
# dtype: object

# %%
data1['poutcome'].replace('unknown', 'nonexistent', inplace = True)
data2['poutcome'].replace('unknown', 'nonexistent', inplace = True)

# %%
data1['y'].mode()
# Out:
# 0    no
# dtype: object

# %%
data2['y'].mode()
# Out:
# 0    no
# dtype: object

# %%
data1['y'].replace('unknown', 'no', inplace = True)
data2['y'].replace('unknown', 'no', inplace = True)

# %%
data1.head()
# Out:
#    age          job  marital          education default housing loan  \
# 0   30  blue-collar  married           basic.9y      no     yes   no
# 1   39     services   single        high.school      no      no   no
# 2   25     services  married        high.school      no     yes   no
# 3   38     services  married           basic.9y      no     yes   no
# 4   47       admin.  married  university.degree      no     yes   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
data2.head()
# Out:
#    age        job  marital    education default housing loan    contact month  \
# 0   56  housemaid  married     basic.4y      no      no   no  telephone   may
# 1   57   services  married  high.school      no      no   no  telephone   may
# 2   37   services  married  high.school      no     yes   no  telephone   may
# 3   40     admin.  married     basic.6y      no      no   no  telephone   may
# 4   56   services  married  high.school      no      no  yes  telephone   may
#
#   day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0         mon  ...         1    999         0  nonexistent          1.1
# 1         mon  ...         1    999         0  nonexistent          1.1
# 2         mon  ...         1    999         0  nonexistent          1.1
# 3         mon  ...         1    999         0  nonexistent          1.1
# 4         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %% [markdown]
# The unknown categorical values in our datasets have hence been dealt with.
